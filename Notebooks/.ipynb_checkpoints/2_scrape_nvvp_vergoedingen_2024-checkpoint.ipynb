# %% [markdown]
# # Scrape NvvP website voor vergoedingen 2024

# %%
import json
import unicodedata
from textwrap import dedent
from pathlib import Path
from copy import deepcopy

from selenium import webdriver
from bs4 import BeautifulSoup

# %%
page_url = "https://www.podotherapie.nl/vergoedingen/"

options = webdriver.ChromeOptions();
options.add_argument('headless');

driver = webdriver.Chrome(options=options)
driver.get(page_url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
articles = soup.find_all('article')[1].find_all('article')

# %%
def html_to_json(part):
    rows = part.find_all("tr")
    
    headers = {}
    thead = part.find("thead")
    if thead:
        thead = thead.find_all("th")
        for i in range(len(thead)):
            headers[i] = thead[i].text.strip().lower()
    data = []
    for row in rows:
        cells = row.find_all("td")
        if thead:
            items = {}
            if len(cells) > 0:
                for index in headers:
                    items[headers[index]] = cells[index].text
        else:
            items = []            
            for index in cells:
                items.append(index.text.strip())
        if items:
            data.append(items)
    
    return data

# %%
providers = {}

for article in articles:
    provider_name = article.find('button').text
    table = article.find('table')
    if table:
        products = html_to_json(table)
        providers[provider_name] = {
            'has_table': True,
            'products': products,
        }
    else:
        info = article.find('p').text
        providers[provider_name] = {
            'has_table': False,
            'info': info,
        }

# %%
len(providers)
# Out:
# 47

# %%
path = Path('./2024/')
if not path.exists():
    path.mkdir()

# %%
with open(path / 'nvvp_tarieven_scrape.json', 'w') as f:
    json.dump(providers, f, indent=4)

# %% [markdown]
# ## Three column format

# %%
table_press = [{
    'verzekeraar': 'Verzekeraar',
    'pakket': 'Pakket',
    'vergoeding': 'Vergoeding',
}]

for provider, data in providers.items():
    if provider == "ASR (De Amersfoortse)":
        products = deepcopy(data['products'])
        info = products.pop()
        additional_info = f"\n{info['pakket']}: {info['vergoeding']}"
        for product in products:
            table_press.append({
                'verzekeraar': provider,
                'pakket': product['pakket'],
                'vergoeding': product['vergoeding'] + f"\n{additional_info}",
            })

    elif data['has_table']:
        for product in data['products']:
            table_press.append({
                'verzekeraar': provider,
                'pakket': product['pakket'],
                'vergoeding': product['vergoeding'],
            })
    else:
        table_press.append({
            'verzekeraar': provider,
            'pakket': '-',
            'vergoeding': data['info'],
        })

with open(path / 'vergoedingen_2023_tablepress_3col.json', 'w') as f:
    json.dump(table_press, f, indent=4)

# %%
table_press
# Out:
# [{'verzekeraar': 'Verzekeraar',
#   'pakket': 'Pakket',
#   'vergoeding': 'Vergoeding'},
#  {'verzekeraar': 'ASR (De Amersfoortse)',
#   'pakket': 'Start',
#   'vergoeding': 'Maximaal € 100,- per jaar door podotherapeut, registerpodoloog of podoposturaal therapeut. Steunzolen* Maximaal € 50,- per jaar\n\n*Steunzolen of therapeutische zolen: Voor deze vergoeding is een verwijzing noodzakelijk. Meer informatie vindt u in de polisvoorwaarden.'},
#  {'verzekeraar': 'ASR (De Amersfoortse)',
#   'pakket': 'Extra',
#   'vergoeding': 'Maximaal € 250,- per jaar door podotherapeut, registerpodoloog of podoposturaal therapeut. Steunzolen* Maximaal € 100,- per jaar\n\n*Steunzolen of therapeutische zolen: Voor deze vergoeding is een verwijzing noodzakelijk. Meer informatie vindt u in de polisvoorwaarden.'},
#  {'verzekeraar': 'ASR (De Amersfoortse)',
#   'pakket': 'Uitgebreid',
#   'vergoeding': 'Maximaal € 500,- per jaar door podotherapeut, registerpodoloog of podoposturaal therapeut. Steunzolen* Maximaal € 150,- per jaar\n\n*Steunzolen of therapeutische zolen: Voor deze vergoeding is een verwijzing noodzakelijk. Meer informatie vindt u in de polisvoorwaarden.'},
#  {'verzekeraar': 'ASR (De Amersfoortse)',
#   'pakket': 'Optimaal',
#   'vergoeding': '100% door podotherapeut,  registerpodoloog of  podoposturaal therapeut. Steunzolen* Maximaal € 200,- per jaar\n\n*Steunzolen of therapeutische zolen: Voor deze vergoeding is een verwijzing noodzakelijk. Meer informatie vindt u in de polisvoorwaarden.'},
#  {'verzekeraar': 'Aevitae',
#   'pakket': 'Prettig',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Aevitae',
#   'pakket': 'Prima',
#   'vergoeding': '€\u202f70,- (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'Aevitae',
#   'pakket': 'Populair',
#   'vergoeding': '€\u202f100,- (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'Aevitae',
#   'pakket': 'Ruim',
#   'vergoeding': '€\u202f150,- (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'Anderzorg',
#   'pakket': 'Extra',
#   'vergoeding': 'Voetzorg € 150,- totaal per jaar'},
#  {'verzekeraar': 'Anderzorg',
#   'pakket': 'Jong',
#   'vergoeding': 'Voetzorg € 150,- totaal per jaar'},
#  {'verzekeraar': 'Anderzorg',
#   'pakket': 'Budget',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Aon IAK',
#   'pakket': '-',
#   'vergoeding': 'Deze verzekeraar biedt collectiviteitskorting via werkgevers, verenigingen of ledenorganisaties. Aon biedt particuliere klanten de CZ Zorgverzekering.'},
#  {'verzekeraar': 'Aon Vitaal',
#   'pakket': 'Basis Vitaal',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Aon Vitaal',
#   'pakket': 'Vitaal 1',
#   'vergoeding': 'Mogelijk een vergoeding via uw collectief'},
#  {'verzekeraar': 'Aon Vitaal',
#   'pakket': 'Vitaal 2',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Aon Vitaal',
#   'pakket': 'Vitaal 3',
#   'vergoeding': 'Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Aon Vitaal',
#   'pakket': 'Vitaal Premium',
#   'vergoeding': 'Max. € 250,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Aon Vitaal',
#   'pakket': 'Vitaal Senior',
#   'vergoeding': 'Max. € 400,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'CZ', 'pakket': 'Start', 'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'CZ', 'pakket': 'Basis', 'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'CZ',
#   'pakket': 'Plus',
#   'vergoeding': '€ 115,- (en € 75,- voor steunzolen)'},
#  {'verzekeraar': 'CZ',
#   'pakket': 'Top',
#   'vergoeding': '€ 115,- (en € 75,- voor steunzolen)'},
#  {'verzekeraar': 'CZ',
#   'pakket': 'Jongeren',
#   'vergoeding': '€ 70,- (en € 60,- voor steunzolen)'},
#  {'verzekeraar': 'CZ',
#   'pakket': 'Gezinnen',
#   'vergoeding': '€ 115,- (en € 60,- voor steunzolen)'},
#  {'verzekeraar': 'CZ',
#   'pakket': '50+',
#   'vergoeding': '€ 115,- (en € 60,- voor steunzolen)'},
#  {'verzekeraar': 'CZdirect',
#   'pakket': '-',
#   'vergoeding': 'Geen vergoeding voor podotherapie in de aanvullende verzekeringen.'},
#  {'verzekeraar': 'DSW',
#   'pakket': 'AV Compact',
#   'vergoeding': '6 behandelingen per jaar (max. € 27,50 per behandeldatum)'},
#  {'verzekeraar': 'DSW',
#   'pakket': 'AV Student',
#   'vergoeding': '6 behandelingen per jaar (max. € 27,50 per behandeldatum); steunzolen max. € 55 per kalenderjaar'},
#  {'verzekeraar': 'DSW',
#   'pakket': 'AV Standaard',
#   'vergoeding': '6 behandelingen per jaar (max. € 27,50 per behandeldatum); steunzolen max. € 55 per kalenderjaar'},
#  {'verzekeraar': 'DSW',
#   'pakket': 'AV Top',
#   'vergoeding': '6 behandelingen per jaar (max. € 27,50 per behandeldatum); steunzolen max. € 75 per kalenderjaar'},
#  {'verzekeraar': 'De Friesland',
#   'pakket': 'AV Instap/Budget/Standaard',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'De Friesland',
#   'pakket': 'AV Extra',
#   'vergoeding': 'Max. € 150 per kalenderjaar; steunzolen max. € 125 per 2 kalenderjaren'},
#  {'verzekeraar': 'De Friesland',
#   'pakket': 'AV Optimaal',
#   'vergoeding': 'Max. € 250 per kalenderjaar; steunzolen max. € 125 per 2 kalenderjaren'},
#  {'verzekeraar': 'De Friesland',
#   'pakket': 'AV Frieso Compleet',
#   'vergoeding': 'Max. € 250 per kalenderjaar; steunzolen 100% max. 1x per kalenderjaar'},
#  {'verzekeraar': 'De christelijke zorgverzekeraar',
#   'pakket': 'Principe Polis',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'De christelijke zorgverzekeraar',
#   'pakket': 'Smallpolis',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'De christelijke zorgverzekeraar',
#   'pakket': 'Mediumpolis',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'De christelijke zorgverzekeraar',
#   'pakket': 'Largepolis',
#   'vergoeding': '€ 150 per kalenderjaar inclusief steunzolen'},
#  {'verzekeraar': 'De christelijke zorgverzekeraar',
#   'pakket': 'Extra Largepolis',
#   'vergoeding': '€ 200 per kalenderjaar inclusief steunzolen'},
#  {'verzekeraar': 'Ditzo',
#   'pakket': 'ZorgBewust',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Ditzo',
#   'pakket': 'ZorgBeter',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Ditzo',
#   'pakket': 'ZorgBest',
#   'vergoeding': 'Podotherapie en steunzolen max. 75% van de rekening, max. € 250 per jaar'},
#  {'verzekeraar': 'FBTO',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie (en steunzolen).'},
#  {'verzekeraar': 'GarantVerzorgd (gemeentepolis via Menzis)',
#   'pakket': 'GarantVerzorgd 1',
#   'vergoeding': 'max. € 150,- per kalenderjaar'},
#  {'verzekeraar': 'GarantVerzorgd (gemeentepolis via Menzis)',
#   'pakket': 'GarantVerzorgd 2',
#   'vergoeding': 'max. € 200,- per kalenderjaar'},
#  {'verzekeraar': 'GarantVerzorgd (gemeentepolis via Menzis)',
#   'pakket': 'GarantVerzorgd 3',
#   'vergoeding': 'max. € 250,- per kalenderjaar'},
#  {'verzekeraar': 'Gemeente Amsterdam (Zilveren Kruis)',
#   'pakket': 'AV Amsterdam 1',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Gemeente Amsterdam (Zilveren Kruis)',
#   'pakket': 'AV Amsterdam 2',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Gemeente Amsterdam (Zilveren Kruis)',
#   'pakket': 'AV Amsterdam 3',
#   'vergoeding': 'Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Gemeente Optimaal (Zilveren Kruis)',
#   'pakket': 'Optimaal Aanvullend 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Gemeente Optimaal (Zilveren Kruis)',
#   'pakket': 'Optimaal Aanvullend 2',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Gemeente Optimaal (Zilveren Kruis)',
#   'pakket': 'Optimaal Aanvullend 3',
#   'vergoeding': 'Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Hema',
#   'pakket': 'Aanvullend 1',
#   'vergoeding': '€ 100,- per kalenderjaar (inclusief steunzolen)'},
#  {'verzekeraar': 'Hema',
#   'pakket': 'Aanvullend 2',
#   'vergoeding': '€ 150,- per kalenderjaar (inclusief steunzolen)'},
#  {'verzekeraar': 'Hema',
#   'pakket': 'Aanvullend 3',
#   'vergoeding': '€ 150,- per kalenderjaar (inclusief steunzolen)'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Extra Zorg Basis',
#   'vergoeding': 'Geen vergoeding voor voetzorg en steunzolen'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Extra Zorg Instap',
#   'vergoeding': 'Geen vergoeding voor voetzorg en steunzolen'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Extra Zorg 1',
#   'vergoeding': '€ 100,- per jaar voor voetzorg en € 125,- voor steunzolen'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Extra Zorg 2',
#   'vergoeding': '€ 200,- per jaar voor voetzorg en € 125,- voor steunzolen'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Extra Zorg 3',
#   'vergoeding': '€ 300,- per jaar voor voetzorg en € 225,- voor steunzolen'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Classic Comfort',
#   'vergoeding': '€ 200,- per jaar voor voetzorg en € 225,- voor steunzolen'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'Fit',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg Instap',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'Gezond',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg + Extra 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg + Extra 2',
#   'vergoeding': '€ 100 voor voetzorg en € 125 voor steunzolen'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg + Extra 3',
#   'vergoeding': '€ 200 voor voetzorg en € 125 voor steunzolen'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Bijzonder Bewust',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'InTwente',
#   'pakket': 'AV Compact',
#   'vergoeding': '6 behandelingen per jaar (max. € 27,50 per behandeldatum); geen vergoeding steunzolen'},
#  {'verzekeraar': 'InTwente',
#   'pakket': 'AV Standaard',
#   'vergoeding': '6 behandelingen per jaar (max. € 27,50 per behandeldatum); steunzolen max. € 55 per kalenderjaar'},
#  {'verzekeraar': 'InTwente',
#   'pakket': 'AV Top',
#   'vergoeding': '6 behandelingen per jaar (max. € 27,50 per behandeldatum); steunzolen max. € 75 per kalenderjaar'},
#  {'verzekeraar': 'InTwente',
#   'pakket': 'AV Student',
#   'vergoeding': '6 behandelingen per jaar (max. € 27,50 per behandeldatum); steunzolen max. € 55 per kalenderjaar'},
#  {'verzekeraar': 'Interpolis',
#   'pakket': 'ZorgActief',
#   'vergoeding': 'Geen vergoeding voor podotherapie (en steunzolen).'},
#  {'verzekeraar': 'Interpolis',
#   'pakket': 'MeerSport – ZonderMeer',
#   'vergoeding': '€ 200,- per kalenderjaar (inclusief steunzolen)'},
#  {'verzekeraar': 'Interpolis',
#   'pakket': 'MeerSport – MeerZeker',
#   'vergoeding': '€ 200,- per kalenderjaar (inclusief steunzolen)'},
#  {'verzekeraar': 'Interpolis',
#   'pakket': 'MeerSport – ZonderZorgen',
#   'vergoeding': '€ 200,- per kalenderjaar (inclusief steunzolen)'},
#  {'verzekeraar': 'Jaaah',
#   'pakket': '-',
#   'vergoeding': 'Zorgverzekering Jaaah gaat verder onder de naam ONVZ Bewuste Keuze!'},
#  {'verzekeraar': 'Just',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie en steunzolen.'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'JongerenVerzorgd',
#   'vergoeding': 'Max. € 150,- per kalenderjaar voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'ExtraVerzorgd 1',
#   'vergoeding': 'Max. € 100,- per kalenderjaar voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'ExtraVerzorgd 2',
#   'vergoeding': 'Max. € 150,- per kalenderjaar voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'ExtraVerzorgd 3',
#   'vergoeding': 'Max. € 200,- per kalenderjaar voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'Mevas',
#   'pakket': 'Aanvullend Metaalunie 1 ster',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Mevas',
#   'pakket': 'Aanvullend Metaalunie 2 sterren',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Mevas',
#   'pakket': 'Aanvullend Metaalunie 3 sterren',
#   'vergoeding': '€ 150,- waaronder 1 paar (sport)steunzolen'},
#  {'verzekeraar': 'Mevas',
#   'pakket': 'Aanvullend Metaalunie 4 sterren',
#   'vergoeding': '€ 200,- waaronder 1 paar (sport)steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Instap',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Start',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Extra',
#   'vergoeding': '€ 100,- en € 100,- voor steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Compleet',
#   'vergoeding': '€ 150,- en € 150,- voor steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Jij & Compact',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Jij & Gemak',
#   'vergoeding': '€ 70,- en € 60,- voor steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Jij & Vitaal',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Comfort',
#   'vergoeding': '€ 150,- en € 200,- voor steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Top',
#   'vergoeding': '€ 150,- en 100% voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Compact/Compact Fysio Meenemen',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Sterk / Sterk Fysio Meenemen',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Aanvullend / Aanvullend Fysio Meenemen',
#   'vergoeding': 'Maximaal € 50,-'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Extra Aanvullend / Extra Aanvullend Fysio Meenemen',
#   'vergoeding': 'Maximaal € 100,- en maximaal € 100 voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Uitgebreid / Uitgebreid Fysio Meenemen',
#   'vergoeding': 'Maximaal € 150,- en maximaal € 150 voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Uitgebreid Vitaal',
#   'vergoeding': 'Maximaal € 150,- en maximaal € 200 voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Extra Uitgebreid',
#   'vergoeding': 'Maximaal € 150,- en maximaal € 200 voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Compleet',
#   'vergoeding': 'Maximaal € 150,- en 100% voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Zelfverzekerd Compact',
#   'vergoeding': 'Maximaal € 50,- en geen vergoeding voor steunzolen'},
#  {'verzekeraar': 'ONVZ',
#   'pakket': 'Startfit',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'ONVZ', 'pakket': 'Benfit', 'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'ONVZ',
#   'pakket': 'Optifit',
#   'vergoeding': 'Max. € 200,- (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'ONVZ',
#   'pakket': 'Topfit',
#   'vergoeding': 'Max. € 500,- (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'PNOzorg',
#   'pakket': '-',
#   'vergoeding': 'PNOzorg is per 1 januari 2023 overgegaan naar ONVZ.'},
#  {'verzekeraar': 'PlusGezond',
#   'pakket': 'Plus Gezond Brons',
#   'vergoeding': '€ 70,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'PlusGezond',
#   'pakket': 'Plus Gezond Zilver',
#   'vergoeding': '€ 100,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'PlusGezond',
#   'pakket': 'Plus Gezond Goud',
#   'vergoeding': '€ 200,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Politie Zorgpolis',
#   'pakket': 'Jongeren PZP',
#   'vergoeding': '€ 70,- voor voetbehandelingen, € 55,-  per jaar voor steunzolen'},
#  {'verzekeraar': 'Politie Zorgpolis',
#   'pakket': 'Jongeren Start PZP',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Politie Zorgpolis',
#   'pakket': 'Basis PZP',
#   'vergoeding': '€ 70,- voor voetbehandelingen, € 55,-  per jaar voor steunzolen'},
#  {'verzekeraar': 'Politie Zorgpolis',
#   'pakket': 'Plus PZP',
#   'vergoeding': '€ 115,- voor voetbehandelingen, € 55,-  per jaar voor steunzolen'},
#  {'verzekeraar': 'Salland Zorgverzekeringen',
#   'pakket': 'Start',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Salland Zorgverzekeringen',
#   'pakket': 'Extra',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Salland Zorgverzekeringen',
#   'pakket': 'Plus',
#   'vergoeding': '75% tot max € 125 per kalenderjaar'},
#  {'verzekeraar': 'Salland Zorgverzekeringen',
#   'pakket': 'Top',
#   'vergoeding': '75% tot max € 250 per kalenderjaar'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Compact AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Jongeren AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar; steunzolen max. € 75,- per kalenderjaar'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Standaard AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar; steunzolen max. € 55,- per kalenderjaar'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Uitgebreide AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar; steunzolen max. € 75,- per kalenderjaar'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Extra Uitgebreide AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar; steunzolen max. € 75,- per kalenderjaar'},
#  {'verzekeraar': 'UMC zorgverzekering',
#   'pakket': 'UMC Extra Zorg Basis',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'UMC zorgverzekering',
#   'pakket': 'UMC Extra Zorg Instap',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'UMC zorgverzekering',
#   'pakket': 'UMC Extra Zorg 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'UMC zorgverzekering',
#   'pakket': 'UMC Extra Zorg 2',
#   'vergoeding': '€ 100 per jaar en € 125 voor steunzolen per jaar'},
#  {'verzekeraar': 'UMC zorgverzekering',
#   'pakket': 'UMC Extra Zorg 3',
#   'vergoeding': '€ 100 per jaar en € 125 voor steunzolen per jaar'},
#  {'verzekeraar': 'United Consumers (VGZ)',
#   'pakket': 'UC ZorgCombi',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'United Consumers (VGZ)',
#   'pakket': 'ZorgBasis',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'United Consumers (VGZ)',
#   'pakket': 'UC ZorgZeker 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'United Consumers (VGZ)',
#   'pakket': 'UC ZorgZeker 2',
#   'vergoeding': '€ 100,- budget voor voetbehandelingen; € 70,- voor steunzolen'},
#  {'verzekeraar': 'United Consumers (VGZ)',
#   'pakket': 'UC ZorgZeker 3',
#   'vergoeding': '€ 200,- budget voor voetbehandelingen; € 125,- voor steunzolen'},
#  {'verzekeraar': 'Univé',
#   'pakket': 'Aanvullend Goed',
#   'vergoeding': '€ 100,- budget voor voetzorg per jaar en € 70,- voor steunzolen'},
#  {'verzekeraar': 'Univé',
#   'pakket': 'Aanvullend Beter',
#   'vergoeding': '€ 300,- budget voor voetzorg per jaar en € 125,- voor steunzolen'},
#  {'verzekeraar': 'Univé',
#   'pakket': 'Aanvullend Best',
#   'vergoeding': '€ 500,- budget voor voetzorg per jaar en € 180,- voor steunzolen'},
#  {'verzekeraar': 'Univé',
#   'pakket': 'Zorg Budget',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Univé',
#   'pakket': 'Zorg Budget Plus',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Univé Zorg Gemeentepakket',
#   'pakket': 'Compact',
#   'vergoeding': '€ 100,- voor voetbehandelingen per jaar en € 70,- voor steunzolen en therapiezolen'},
#  {'verzekeraar': 'Univé Zorg Gemeentepakket',
#   'pakket': 'Compleet',
#   'vergoeding': '€ 300,- voor voetbehandelingen per jaar en € 125,- voor steunzolen en therapiezolen'},
#  {'verzekeraar': 'VGZ', 'pakket': 'Instap', 'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Aanvullend Goed',
#   'vergoeding': '€ 100,- (en € 70,- voor steunzolen)'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Aanvullend Beter',
#   'vergoeding': '€ 300,- budget voor voetzorg (en € 125,- voor steunzolen)'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Aanvullend Best',
#   'vergoeding': '€ 500,- budget voor voetzorg (en € 180,- voor steunzolen)'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Alles-in-1 VGZ Jongpakket',
#   'vergoeding': 'Geen vergoeding voor voetzorg en steunzolen'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Alles-in-1 VGZ Gezinpakket',
#   'vergoeding': '€ 300,- per jaar voor podotherapie en voetbehandelingen (en € 125,- voor steunzolen)'},
#  {'verzekeraar': 'VGZ Werkt',
#   'pakket': 'Instap',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'VGZ Werkt',
#   'pakket': 'werkt Goed',
#   'vergoeding': '€ 100,- (en € 70,- voor steunzolen)'},
#  {'verzekeraar': 'VGZ Werkt',
#   'pakket': 'Werkt Beter',
#   'vergoeding': '€ 300,- budget voor voetzorg (en € 125,- voor steunzolen)'},
#  {'verzekeraar': 'VGZ Werkt',
#   'pakket': 'Werkt Best',
#   'vergoeding': '€ 500,- budget voor voetzorg (en € 180,- voor steunzolen)'},
#  {'verzekeraar': 'VinkVink',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie en steunzolen.'},
#  {'verzekeraar': 'Vrieling Zorgverzekering',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie en steunzolen.'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Student',
#   'vergoeding': 'Geen vergoeding voor voetzorg en steunzolen'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Start',
#   'vergoeding': 'Geen vergoeding voor voetzorg en steunzolen'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Plus',
#   'vergoeding': 'Geen vergoeding voor voetzorg en steunzolen'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Optimaal',
#   'vergoeding': '€ 200,- per jaar budget voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Top',
#   'vergoeding': '€ 500,- per jaar budget voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Excellent',
#   'vergoeding': 'Volledig vergoed, max. € 500,- voor steunzolen per kalenderjaar'},
#  {'verzekeraar': 'ZEKUR',
#   'pakket': 'Extra ZEKUR',
#   'vergoeding': '€ 200 budget voor voetbehandelingen; € 125 voor steunzolen.'},
#  {'verzekeraar': 'ZieZo van Zilveren Kruis',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie (en steunzolen).'},
#  {'verzekeraar': 'Zilveren Kruis',
#   'pakket': 'Aanvullend 1 Ster',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Zilveren Kruis',
#   'pakket': 'Aanvullend 2 Sterren',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Zilveren Kruis',
#   'pakket': 'Aanvullend 3 Sterren',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Zilveren Kruis',
#   'pakket': 'Aanvullend 4 Sterren',
#   'vergoeding': 'Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV Basis',
#   'vergoeding': 'Max. € 50,- vergoeding per kalenderjaar en 50% voor steunzolen tot maximaal € 35,-'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV Standaard',
#   'vergoeding': 'Max. € 50,- vergoeding per kalenderjaar en 50% voor steunzolen tot maximaal € 35,-'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV Top',
#   'vergoeding': 'Max. € 100,- vergoeding per kalenderjaar en tot max. € 70,- voor steunzolen'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV Plus',
#   'vergoeding': 'Max. € 100,- vergoeding per kalenderjaar en tot max. € 70,- voor steunzolen. Voetzorg bij diabetes of reuma € 210,- per kalenderjaar.'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV GeZZin',
#   'vergoeding': 'Max. € 100,- vergoeding per kalenderjaar en tot max. € 70,- voor steunzolen'},
#  {'verzekeraar': 'ZorgDirect',
#   'pakket': '-',
#   'vergoeding': 'ZorgDirect is in 2023 Salland geworden.'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 2',
#   'vergoeding': '€ 100 per jaar voor podotherapie en voetbehandelingen Geen vergoeding voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 3',
#   'vergoeding': '€ 100 per jaar voor podotherapie en voetbehandelingen Geen vergoeding voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 4',
#   'vergoeding': '€ 200 per jaar voor podotherapie en voetbehandelingen Geen vergoeding voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 5',
#   'vergoeding': '€ 200 per jaar voor podotherapie en voetbehandelingen. € 70 voor aanmeten en kosten van steunzolen en therapiezolen.'}]
