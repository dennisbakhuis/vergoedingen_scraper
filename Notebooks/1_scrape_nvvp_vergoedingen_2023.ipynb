# %% [markdown]
# # Scrape NvvP website voor vergoedingen

# %%
import json
import unicodedata
from textwrap import dedent

from selenium import webdriver
from bs4 import BeautifulSoup

# %%
page_url = "https://www.podotherapie.nl/vergoedingen/"

options = webdriver.ChromeOptions();
options.add_argument('headless');

driver = webdriver.Chrome(options=options)
driver.get(page_url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
h2_tags = soup.find_all('h2', attrs={'class': 'sluiter'})

# %%
def remove_unicode(input_string) -> str:
    return unicodedata.normalize('NFKD', input_string).encode('ascii', 'ignore').decode()


def html_to_json(part):
    rows = part.find_all("tr")
    
    headers = {}
    thead = part.find("thead")
    if thead:
        thead = thead.find_all("th")
        for i in range(len(thead)):
            headers[i] = thead[i].text.strip().lower()
    data = []
    for row in rows:
        cells = row.find_all("td")
        if thead:
            items = {}
            if len(cells) > 0:
                for index in headers:
                    items[headers[index]] = cells[index].text
                    return cells[index].text
        else:
            items = []            
            for index in cells:
                items.append(index.text.strip())
        if items:
            data.append(items)
    
    products = {
        name: information
        for name, information in data[1:]
    }
    
    return products

# %%
providers = {}

for h2_tag in h2_tags:
    provider_name = remove_unicode(h2_tag.text)
    info_div = h2_tag.find_next_sibling("div")
    if info_div:
        table = info_div.find('table')
        if table:
            products = html_to_json(table)
            providers[provider_name] = {
                'has_table': True,
                'products': products,
            }
        else:
            info = info_div.find('p')
            providers[provider_name] = {
                'has_table': False,
                'info': info.text.strip(),
            }

# %%
len(providers)
# Out:
# 0

# %%
with open('nvvp_tarieven_scrape.json', 'w') as f:
    json.dump(providers, f, indent=4)

# %% [markdown]
# ## Two column format

# %%
table_press = [{
    'pakket_naam': 'Verzekeringspakket',
    'vergoeding': 'Vergoeding',
}]

for provider, data in providers.items():
    if data['has_table']:
        for product, info in data['products'].items():
            table_press.append({
                'pakket_naam': f'{provider} - {product}',
                'vergoeding': info,
            })
    else:
        table_press.append({
            'pakket_naam': provider,
            'vergoeding': data['info'],
        })

with open('vergoedingen_2023_tablepress_2col.json', 'w') as f:
    json.dump(table_press, f, indent=4)

# %% [markdown]
# ## Three column format

# %%
table_press = [{
    'verzekeraar': 'Verzekeraar',
    'pakket': 'Pakket',
    'vergoeding': 'Vergoeding',
}]

for provider, data in providers.items():
    if data['has_table']:
        for product, info in data['products'].items():
            table_press.append({
                'verzekeraar': provider,
                'pakket': product,
                'vergoeding': info,
            })
    else:
        table_press.append({
            'verzekeraar': provider,
            'pakket': '-',
            'vergoeding': data['info'],
        })

with open('vergoedingen_2023_tablepress_3col.json', 'w') as f:
    json.dump(table_press, f, indent=4)

# %%
def create_html_object(name, data):
    if data['has_table']:
        table_data = '<tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr>'
        for pakket, pakket_info in data['products'].items():
            table_data += f'<tr><th scope="row">{pakket}</th><td>{pakket_info}</td></tr>'
        info = f'<table class="verzekeraar-vergoeding-table">{table_data}</table>'
    else:
        info = f'<p class="verzekeraar-vergoeding-info">{data["info"]}</p>'
    
    html_code = dedent(f"""\
    <div class="verzekeraar">
        <h4 class="verzekeraar-titel">{name}</h4>
        <div class="verzekeraar-vergoeding">
            {info}
        </div>
    </div>
    """)
    
    return html_code.strip()

# %%
html_objects = ""
for provider, provider_data in providers.items():
    html_objects += create_html_object(provider, provider_data)

# %%
with open('vergoedingen_verzekeraars.html', 'w') as f:
    f.write(html_objects)

# %%
print(html_objects)
# Out:
# <div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Aevitea</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Prettig</th><td>Geen vergoeding</td></tr><tr><th scope="row">Prima</th><td>€ 70,- (inclusief steunzolen) per kalenderjaar</td></tr><tr><th scope="row">Populair</th><td>€ 100,- (inclusief steunzolen) per kalenderjaar</td></tr><tr><th scope="row">Ruim</th><td>€ 150,- (inclusief steunzolen) per kalenderjaar</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Anderzorg</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Extra</th><td>Voetzorg € 150,- totaal per jaar</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Aon IAK </h4>
#         <div class="verzekeraar-vergoeding">
#             <p class="verzekeraar-vergoeding-info">Deze verzekeraar biedt collectiviteitskorting via werkgevers, verenigingen
# of ledenorganisaties. Aon biedt particuliere klanten de CZ Zorgverzekering.</p>
#         </div>
#     </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Aon Vitaal (Zilveren Kruis)</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Basis Vitaal</th><td>Geen vergoeding</td></tr><tr><th scope="row">Vitaal 1</th><td>Geen vergoeding</td></tr><tr><th scope="row">Vitaal 2</th><td>Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">Vitaal 3</th><td>Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">Vitaal Premium</th><td>Max. € 250,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">Vitaal Senior</th><td>Max. € 400,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">ASR/De Amersfoortse</h4>
#     <div class="verzekeraar-vergoeding">
#         <p class="verzekeraar-vergoeding-info">De Amersfoortse gaat sinds april 2021 verder onder de naam a.s.r.</p>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">CZ</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Start</th><td>Geen vergoeding</td></tr><tr><th scope="row">Basis</th><td>Geen vergoeding</td></tr><tr><th scope="row">50+</th><td>€ 115,- (en € 60,- voor steunzolen)</td></tr><tr><th scope="row">Jongeren</th><td>€ 70,- (en € 60,- voor steunzolen)</td></tr><tr><th scope="row">Plus</th><td>€ 115,- (en € 75,- voor steunzolen)</td></tr><tr><th scope="row">Top</th><td>€ 115,- (en € 75,- voor steunzolen)</td></tr><tr><th scope="row">Gezinnen</th><td>€ 115,- (en € 60,- voor steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">CZdirect</h4>
#     <div class="verzekeraar-vergoeding">
#         <p class="verzekeraar-vergoeding-info">Geen vergoeding voor podotherapie in de aanvullende verzekeringen.</p>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">De Friesland</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">AV Instap/Budget/Standaard</th><td>Geen vergoeding</td></tr><tr><th scope="row">AV Extra</th><td>Max. € 150 per kalenderjaar; steunzolen max. € 125 per 2 kalenderjaren</td></tr><tr><th scope="row">AV Optimaal</th><td>Max. € 250 per kalenderjaar; steunzolen max. € 125 per 2 kalenderjaren</td></tr><tr><th scope="row">AV Frieso Compleet</th><td>Max. € 250 per kalenderjaar; steunzolen 100% max. 1x per kalenderjaar</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Ditzo</h4>
#         <div class="verzekeraar-vergoeding">
#             <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">ZorgBewust</th><td>Geen vergoeding</td></tr><tr><th scope="row">ZorgBeter</th><td>Geen vergoeding</td></tr><tr><th scope="row">ZorgBest</th><td>Podotherapie en steunzolen max. 75% van de rekening, max. € 250 per
# jaar</td></tr></table>
#         </div>
#     </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">DSW</h4>
#         <div class="verzekeraar-vergoeding">
#             <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">AV Compact</th><td>6 behandelingen per jaar (max. € 27,50 per behandeldatum)</td></tr><tr><th scope="row">AV Student</th><td>6 behandelingen per jaar (max. € 27,50 per behandeldatum);
# steunzolen max. € 55 per kalenderjaar</td></tr><tr><th scope="row">AV Standaard</th><td>6 behandelingen per jaar (max. € 27,50 per behandeldatum);
# steunzolen max. € 55 per kalenderjaar</td></tr><tr><th scope="row">AV Top</th><td>6 behandelingen per jaar (max. € 27,50 per behandeldatum);
# steunzolen max. € 75 per kalenderjaar</td></tr></table>
#         </div>
#     </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">FBTO</h4>
#         <div class="verzekeraar-vergoeding">
#             <p class="verzekeraar-vergoeding-info">Deze zorgverzekeraar biedt vanuit de aanvullende verzekering
# geen vergoeding voor podotherapie (en steunzolen).</p>
#         </div>
#     </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">GarantVerzorgd (gemeentepolis via Menzis)</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">GarantVerzorgd 1</th><td>max. € 150,- per kalenderjaar</td></tr><tr><th scope="row">GarantVerzorgd 2</th><td>max. € 200,- per kalenderjaar</td></tr><tr><th scope="row">GarantVerzorgd 3</th><td>max. € 250,- per kalenderjaar</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Hema</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Aanvullend 1</th><td>€ 100,- per kalenderjaar (inclusief steunzolen)</td></tr><tr><th scope="row">Aanvullend 2</th><td>€ 150,- per kalenderjaar (inclusief steunzolen)</td></tr><tr><th scope="row">Aanvullend 3</th><td>€ 150,- per kalenderjaar (inclusief steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Interpolis</h4>
#         <div class="verzekeraar-vergoeding">
#             <p class="verzekeraar-vergoeding-info">Deze zorgverzekeraar biedt vanuit de aanvullende verzekering
# geen vergoeding voor podotherapie (en steunzolen).</p>
#         </div>
#     </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">inTwente</h4>
#         <div class="verzekeraar-vergoeding">
#             <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">AV Compact</th><td>6 behandelingen per jaar (max. € 27,50 per behandeldatum);
# geen vergoeding steunzolen</td></tr><tr><th scope="row">AV Standaard</th><td>6 behandelingen per jaar (max. € 27,50 per behandeldatum);
# steunzolen max. € 55 per kalenderjaar</td></tr><tr><th scope="row">AV Top</th><td>6 behandelingen per jaar (max. € 27,50 per behandeldatum);
# steunzolen max. € 55 per kalenderjaar</td></tr><tr><th scope="row">AV Student</th><td>6 behandelingen per jaar (max. € 27,50 per behandeldatum);
# steunzolen max. € 75 per kalenderjaar</td></tr></table>
#         </div>
#     </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">IZA</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">IZA Extra Zorg 1</th><td>€ 100,- per jaar voor voetzorg en € 125,- voor steunzolen</td></tr><tr><th scope="row">IZA Extra Zorg 2</th><td>€ 200,- per jaar voor voetzorg en € 125,- voor steunzolen</td></tr><tr><th scope="row">IZA Extra Zorg 3</th><td>€ 300,- per jaar voor voetzorg en € 225,- voor steunzolen</td></tr><tr><th scope="row">IZA Extra Zorg Instap</th><td>Geen vergoeding voor voetzorg en steunzolen</td></tr><tr><th scope="row">IZA Classic Comfort</th><td>€ 200,- per jaar voor voetzorg en € 225,- voor steunzolen</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">IZZ door VGZ</h4>
#         <div class="verzekeraar-vergoeding">
#             <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">IZZ Instap</th><td>Geen vergoeding voor podotherapie en steunzolen</td></tr><tr><th scope="row">Zorg voor de Zorg</th><td>Geen vergoeding voor podotherapie en steunzolen</td></tr><tr><th scope="row">Zorg voor de Zorg Extra 1</th><td>Geen vergoeding voor podotherapie en steunzolen</td></tr><tr><th scope="row">Zorg voor de Zorg Extra 2</th><td>€ 100,- per jaar voor podotherapie en voetbehandelingen
# en € 125,- voor steunzolen</td></tr><tr><th scope="row">Zorg voor de Zorg Extra 3</th><td>€ 200,- per jaar voor podotherapie en voetbehandelingen
# en € 125,- voor steunzolen</td></tr><tr><th scope="row">Bijzonder Bewust</th><td>Geen vergoeding voor podotherapie en steunzolen</td></tr></table>
#         </div>
#     </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Jaah</h4>
#         <div class="verzekeraar-vergoeding">
#             <p class="verzekeraar-vergoeding-info">Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding
# voor podotherapie en steunzolen.</p>
#         </div>
#     </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Just</h4>
#         <div class="verzekeraar-vergoeding">
#             <p class="verzekeraar-vergoeding-info">Deze zorgverzekeraar biedt vanuit de aanvullende verzekering
# geen vergoeding voor podotherapie en steunzolen.</p>
#         </div>
#     </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Menzis</h4>
#         <div class="verzekeraar-vergoeding">
#             <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">ExtraVerzorgd 1</th><td>Max. € 100,- per kalenderjaar voor voetzorg (inclusief
# steunzolen)</td></tr><tr><th scope="row">ExtraVerzorgd 2</th><td>Max. € 150,- per kalenderjaar voor voetzorg (inclusief
# steunzolen)</td></tr><tr><th scope="row">ExtraVerzorgd 3</th><td>Max. € 200,- per kalenderjaar voor voetzorg (inclusief
# steunzolen)</td></tr><tr><th scope="row">JongerenVerzorgd</th><td>Max. € 150,- per kalenderjaar voor voetzorg (inclusief steunzolen)</td></tr><tr><th scope="row">Aanvullend</th><td>Geen vergoeding</td></tr><tr><th scope="row">Extra Aanvullend</th><td>Geen vergoeding</td></tr></table>
#         </div>
#     </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Mevas</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">AV 1 ster</th><td>Geen vergoeding</td></tr><tr><th scope="row">AV 2 sterren</th><td>Geen vergoeding</td></tr><tr><th scope="row">AV 3 sterren</th><td>€ 150,- waaronder 1 paar (sport)steunzolen</td></tr><tr><th scope="row">AV 4 sterren</th><td>€ 200,- waaronder 1 paar (sport) steunzolen</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Nationale Nederlanden</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Start</th><td>Geen vergoeding</td></tr><tr><th scope="row">Extra</th><td>€ 100,- en € 100,- voor steunzolen</td></tr><tr><th scope="row">Compleet</th><td>€ 150,- en € 150,- voor steunzolen</td></tr><tr><th scope="row">Comfort</th><td>€ 150,- en € 200,- voor steunzolen</td></tr><tr><th scope="row">Top</th><td>€ 150,- en 100% voor steunzolen</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">OHRA</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Aanvullend/Aanvullend Fysio Meenemen</th><td>Max. € 50,-</td></tr><tr><th scope="row">Extra aanvullend/Extra Aanvullend Fysio Meenemen</th><td>Max. € 100,- en € 100,- voor steunzolen</td></tr><tr><th scope="row">Uitgebreid</th><td>Max. € 150,- en € 150,- voor steunzolen</td></tr><tr><th scope="row">Uitgebreid Vitaal</th><td>Max. € 150,- en € 200,- voor steunzolen</td></tr><tr><th scope="row">Extra Uitgebreid</th><td>Max. € 150,- en € 200,- voor steunzolen</td></tr><tr><th scope="row">Compleet</th><td>Max. € 150,- en volledige vergoeding voor steunzolen</td></tr><tr><th scope="row">Zelfverzekerd Compact</th><td>Max. € 50,-  en geen vergoeding voor steunzolen</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">ONVZ</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Startfit</th><td>Geen vergoeding</td></tr><tr><th scope="row">Benfit</th><td>Geen vergoeding</td></tr><tr><th scope="row">Topfit</th><td>Max. € 500,- (inclusief steunzolen) per kalenderjaar</td></tr><tr><th scope="row">Optifit</th><td>Max. € 200,- (inclusief steunzolen) per kalenderjaar</td></tr><tr><th scope="row">Superfit</th><td>Podotherapie 100% en € 500,- voor steunzolen per kalenderjaar</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Plus Gezond</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Plus Gezond Brons</th><td>€ 70,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">Plus Gezond Zilver</th><td>€ 100,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">Plus Gezond Goud</th><td>€ 200,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">PNOzorg</h4>
#     <div class="verzekeraar-vergoeding">
#         <p class="verzekeraar-vergoeding-info">PNOzorg gaat per 1 januari 2023 over naar ONVZ.</p>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Politie Zorg Polis</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Jongeren PZP</th><td>€ 70,- voor voetbehandelingen, € 55,-  per jaar voor steunzolen</td></tr><tr><th scope="row">Basis PZP</th><td>€ 70,- voor voetbehandelingen, € 55,-  per jaar voor steunzolen</td></tr><tr><th scope="row">Plus PZP</th><td>€ 115,- voor voetbehandelingen, € 55,-  per jaar voor steunzolen</td></tr><tr><th scope="row">Jongeren Start PZP</th><td>Geen vergoeding</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Pro Life</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Smallpolis</th><td>Geen vergoeding</td></tr><tr><th scope="row">Mediumpolis</th><td>Geen vergoeding</td></tr><tr><th scope="row">Largepolis</th><td>Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">Extra Largepolis</th><td>Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Salland Zorgverzekeringen</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Start</th><td>Geen vergoeding</td></tr><tr><th scope="row">Extra</th><td>Geen vergoeding</td></tr><tr><th scope="row">Plus</th><td>75% tot maximaal € 125,- per kalenderjaar (inclusief steunzolen)</td></tr><tr><th scope="row">Top</th><td>75% tot maximaal € 250,- per kalenderjaar (inclusief steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Stad Holland</h4>
#         <div class="verzekeraar-vergoeding">
#             <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Compact AV</th><td>Max. € 27,50 per behandeldatum, max. 6 behandelingen per
# kalenderjaar</td></tr><tr><th scope="row">Jongeren AV</th><td>Max. € 27,50 per behandeldatum, max. 6 behandelingen per
# kalenderjaar; steunzolen max. € 75,- per kalenderjaar</td></tr><tr><th scope="row">Standaard AV</th><td>Max. € 27,50 per behandeldatum, max. 6 behandelingen per
# kalenderjaar; steunzolen max. € 55,- per kalenderjaar</td></tr><tr><th scope="row">Uitgebreide AV</th><td>Max. € 27,50 per behandeldatum, max. 6 behandelingen per
# kalenderjaar; steunzolen max. € 75,- per kalenderjaar</td></tr><tr><th scope="row">Extra Uitgebreide AV</th><td>Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar;
# steunzolen max. € 75,- per kalenderjaar</td></tr></table>
#         </div>
#     </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">UMC</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Extra Zorg Instap</th><td>Geen vergoeding</td></tr><tr><th scope="row">Extra Zorg 1</th><td>Geen vergoeding</td></tr><tr><th scope="row">Extra Zorg 2</th><td>€ 100,- per jaar en € 125,- voor steunzolen</td></tr><tr><th scope="row">Extra Zorg 3</th><td>€ 100,- per jaar en € 125,- voor steunzolen</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">United Consumers (VGZ)</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">ZorgZeker 1</th><td>Geen vergoeding</td></tr><tr><th scope="row">ZorgZeker 2</th><td>€ 100,- budget voor voetbehandelingen; € 70,- voor steunzolen</td></tr><tr><th scope="row">ZorgZeker 3</th><td>€ 200,- budget voor voetbehandelingen; € 125,- voor steunzolen</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Unive</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Aanvullend Goed</th><td>€ 100,- budget voor voetzorg per jaar en € 70,- voor steunzolen</td></tr><tr><th scope="row">Aanvullend Beter</th><td>€ 300,- budget voor voetzorg per jaar en € 125,- voor steunzolen</td></tr><tr><th scope="row">Aanvullend Best</th><td>€ 500,- budget voor voetzorg per jaar en € 180,- voor steunzolen</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">VGZ</h4>
#         <div class="verzekeraar-vergoeding">
#             <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Instap</th><td>Geen vergoeding</td></tr><tr><th scope="row">Aanvullend Goed</th><td>€ 100,- (en € 70,- voor steunzolen)</td></tr><tr><th scope="row">Aanvullend Beter</th><td>€ 300,- budget voor voetzorg (en € 125,- voor steunzolen)</td></tr><tr><th scope="row">Aanvullend Best</th><td>€ 500,- budget voor voetzorg (en € 180,- voor steunzolen)</td></tr><tr><th scope="row">Alles-in-1 VGZ Jongpakket</th><td>Geen vergoeding voor voetzorg en steunzolen</td></tr><tr><th scope="row">Alles-in-1 VGZ Gezinpakket</th><td>€ 300,- per jaar voor podotherapie en voetbehandelingen (en € 125,-
# voor steunzolen)</td></tr></table>
#         </div>
#     </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">VGZbewuzt</h4>
#         <div class="verzekeraar-vergoeding">
#             <p class="verzekeraar-vergoeding-info">Deze zorgverzekeraar biedt vanuit de aanvullende verzekering
# geen vergoeding voor podotherapie (en steunzolen).</p>
#         </div>
#     </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">VGZ Werkt</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Werkt Goed</th><td>€ 100,- (en € 70,- voor steunzolen)</td></tr><tr><th scope="row">Werkt Beter</th><td>€ 300,- budget voor voetzorg (en € 125,- voor steunzolen)</td></tr><tr><th scope="row">Werkt Best</th><td>€ 500,- budget voor voetzorg (en € 180,- voor steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">VGZ voor de Zorg</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">IZZ Instap</th><td>Geen vergoeding</td></tr><tr><th scope="row">IZZ Zorg voor de zorg</th><td>Geen vergoeding</td></tr><tr><th scope="row">IZZ Zorg voor de zorg + Extra 1</th><td>Geen vergoeding</td></tr><tr><th scope="row">IZZ Zorg voor de zorg + Extra 2</th><td>€ 100,- budget voor voetzorg (en € 125,- voor steunzolen)</td></tr><tr><th scope="row">IZZ Zorg voor de zorg + Extra 3</th><td>€ 200,- budget voor voetzorg (en € 125,- voor steunzolen)</td></tr><tr><th scope="row">Bijzonder Bewust</th><td>Geen vergoeding</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">VinkVink</h4>
#         <div class="verzekeraar-vergoeding">
#             <p class="verzekeraar-vergoeding-info">Deze zorgverzekeraar biedt vanuit de aanvullende verzekering
# geen vergoeding voor podotherapie en steunzolen.</p>
#         </div>
#     </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Vrieling Zorgverzekeraar</h4>
#         <div class="verzekeraar-vergoeding">
#             <p class="verzekeraar-vergoeding-info">Deze zorgverzekeraar biedt vanuit de aanvullende verzekering
# geen vergoeding voor podotherapie en steunzolen.</p>
#         </div>
#     </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">VvAA</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Student</th><td>Geen vergoeding voor voetzorg en steunzolen</td></tr><tr><th scope="row">Start</th><td>Geen vergoeding voor voetzorg en steunzolen</td></tr><tr><th scope="row">Plus</th><td>Geen vergoeding voor voetzorg en steunzolen</td></tr><tr><th scope="row">Optimaal</th><td>€ 200,- per jaar budget voor voetzorg (inclusief steunzolen)</td></tr><tr><th scope="row">Top</th><td>€ 500,- per jaar budget voor voetzorg (inclusief steunzolen)</td></tr><tr><th scope="row">Excellent</th><td>Volledig vergoed, max. € 500,- voor steunzolen per kalenderjaar</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">ZEKUR</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Extra ZEKUR</th><td>€ 200 budget voor voetbehandelingen; € 125 voor steunzolen</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">ZieZo van Zilveren Kruis</h4>
#         <div class="verzekeraar-vergoeding">
#             <p class="verzekeraar-vergoeding-info">Deze zorgverzekeraar biedt vanuit de aanvullende verzekering
# geen vergoeding voor podotherapie (en steunzolen).</p>
#         </div>
#     </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Zilveren Kruis</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Aanvullend 1 Ster</th><td>Geen vergoeding</td></tr><tr><th scope="row">Aanvullend 2 Sterren</th><td>Geen vergoeding</td></tr><tr><th scope="row">Aanvullend 3 Sterren</th><td>Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">Aanvullend 4 Sterren</th><td>Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Gemeente Optimaal (Zilveren Kruis)</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Optimaal Aanvullend 1</th><td>Geen vergoeding</td></tr><tr><th scope="row">Optimaal Aanvullend 2</th><td>Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">Optimaal Aanvullend 3</th><td>Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">Gemeente Amsterdam (Zilveren Kruis)</h4>
#     <div class="verzekeraar-vergoeding">
#         <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">AV Amsterdam 1</th><td>Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">AV Amsterdam 2</th><td>Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr><tr><th scope="row">AV Amsterdam 3</th><td>Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)</td></tr></table>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Zorg en Zekerheid</h4>
#         <div class="verzekeraar-vergoeding">
#             <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">AV Basis</th><td>Max. € 50,- vergoeding per kalenderjaar en 50% voor steunzolen tot
# maximaal € 35,-</td></tr><tr><th scope="row">AV Standaard</th><td>Max. € 50,- vergoeding per kalenderjaar en 50% voor steunzolen
# tot maximaal € 35,-</td></tr><tr><th scope="row">AV Top</th><td>Max. € 100,- vergoeding per kalenderjaar en tot max. €
# 70,- voor steunzolen</td></tr><tr><th scope="row">AV Plus</th><td>Max. € 100,- vergoeding per kalenderjaar en tot max. €
# 70,- voor steunzolen</td></tr><tr><th scope="row">AV GeZZin</th><td>Max. € 100,- vergoeding per kalenderjaar en tot max. €
# 70,- voor steunzolen</td></tr></table>
#         </div>
#     </div><div class="verzekeraar">
#     <h4 class="verzekeraar-titel">ZorgDirect</h4>
#     <div class="verzekeraar-vergoeding">
#         <p class="verzekeraar-vergoeding-info">ZorgDirect wordt in 2023 Salland.</p>
#     </div>
# </div><div class="verzekeraar">
#         <h4 class="verzekeraar-titel">Zorgzaam</h4>
#         <div class="verzekeraar-vergoeding">
#             <table class="verzekeraar-vergoeding-table"><tr><th scope="col">Pakket</th><th scope="col">Vergoeding</th></tr><tr><th scope="row">Zorgzaam Aanvullend Ster 1</th><td>Geen vergoeding</td></tr><tr><th scope="row">Zorgzaam Aanvullend Ster 2</th><td>€ 100 per jaar voor podotherapie en voetbehandelingen</td></tr><tr><th scope="row">Zorgzaam Aanvullend Ster 3</th><td>€ 100 per jaar voor podotherapie en voetbehandelingen</td></tr><tr><th scope="row">Zorgzaam Aanvullend Ster 4</th><td>€ 200 per jaar voor podotherapie en voetbehandelingen</td></tr><tr><th scope="row">Zorgzaam Aanvullend Ster 5</th><td>€ 200 per jaar voor podotherapie en voetbehandelingen en
# € 70 voor steunzolen</td></tr></table>
#         </div>
#     </div>
