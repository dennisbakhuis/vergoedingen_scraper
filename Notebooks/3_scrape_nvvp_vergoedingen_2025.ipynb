# %% [markdown]
# # Scrape NvvP website voor vergoedingen 2024

# %%
import json
import unicodedata
from textwrap import dedent
from pathlib import Path
from copy import deepcopy

from selenium import webdriver
from bs4 import BeautifulSoup

# %%
YEAR = "2025"

page_url = "https://www.podotherapie.nl/vergoedingen/"

options = webdriver.ChromeOptions();
options.add_argument('headless');

driver = webdriver.Chrome(options=options)
driver.get(page_url)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
articles = soup.find_all('article')[1].find_all('article')

# %%
def html_to_json(part):
    rows = part.find_all("tr")
    
    headers = {}
    thead = part.find("thead")
    if thead:
        thead = thead.find_all("th")
        for i in range(len(thead)):
            headers[i] = thead[i].text.strip().lower()
    data = []
    for row in rows:
        cells = row.find_all("td")
        if thead:
            items = {}
            if len(cells) > 0:
                for index in headers:
                    items[headers[index]] = cells[index].text
        else:
            items = []            
            for index in cells:
                items.append(index.text.strip())
        if items:
            data.append(items)
    
    return data

# %%
providers = {}

for article in articles:
    provider_name = article.find('button').text
    table = article.find('table')
    if table:
        products = html_to_json(table)
        providers[provider_name] = {
            'has_table': True,
            'products': products,
        }
    else:
        info = article.find('p').text
        providers[provider_name] = {
            'has_table': False,
            'info': info,
        }

# %%
len(providers)
# Out:
# 43

# %%
path = Path(f'./{YEAR}/')
if not path.exists():
    path.mkdir()

# %%
with open(path / 'nvvp_tarieven_scrape.json', 'w') as f:
    json.dump(providers, f, indent=4)

# %% [markdown]
# ## Three column format

# %%
table_press = [{
    'verzekeraar': 'Verzekeraar',
    'pakket': 'Pakket',
    'vergoeding': 'Vergoeding',
}]

for provider, data in providers.items():
    if provider == "ASR (De Amersfoortse)":
        products = deepcopy(data['products'])
        info = products.pop()
        additional_info = f"\n{info['pakket']}: {info['vergoeding']}"
        for product in products:
            table_press.append({
                'verzekeraar': provider,
                'pakket': product['pakket'],
                'vergoeding': product['vergoeding'] + f"\n{additional_info}",
            })

    elif data['has_table']:
        for product in data['products']:
            table_press.append({
                'verzekeraar': provider,
                'pakket': product['pakket'],
                'vergoeding': product['vergoeding'],
            })
    else:
        table_press.append({
            'verzekeraar': provider,
            'pakket': '-',
            'vergoeding': data['info'],
        })

with open(path / f'vergoedingen_{YEAR}_tablepress_3col.json', 'w') as f:
    json.dump(table_press, f, indent=4)

# %%
table_press
# Out:
# [{'verzekeraar': 'Verzekeraar',
#   'pakket': 'Pakket',
#   'vergoeding': 'Vergoeding'},
#  {'verzekeraar': 'Aevitea',
#   'pakket': 'Laef!1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Aevitea',
#   'pakket': 'Laef!2',
#   'vergoeding': '€\u202f70,- (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'Aevitea',
#   'pakket': 'Laef!3',
#   'vergoeding': '€\u202f100,- (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'Aevitea',
#   'pakket': 'Laef!4',
#   'vergoeding': '€\u202f150,- (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'Anderzorg',
#   'pakket': 'Flex',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Anderzorg',
#   'pakket': 'Extra',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Aon Vitaal (Zilveren Kruis)',
#   'pakket': 'Basis Vitaal',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Aon Vitaal (Zilveren Kruis)',
#   'pakket': 'Vitaal 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Aon Vitaal (Zilveren Kruis)',
#   'pakket': 'Vitaal 2',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Aon Vitaal (Zilveren Kruis)',
#   'pakket': 'Vitaal 3',
#   'vergoeding': 'Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Aon Vitaal (Zilveren Kruis)',
#   'pakket': 'Vitaal Premium',
#   'vergoeding': 'Max. € 250,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Aon Vitaal (Zilveren Kruis)',
#   'pakket': 'Vitaal Senior',
#   'vergoeding': 'Max. € 400,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'CZ', 'pakket': 'Start', 'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'CZ', 'pakket': 'Basis', 'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'CZ',
#   'pakket': '50+',
#   'vergoeding': '€ 115,- (en € 60,- Voetzorg hulpmiddelen zoals zooltjes, tape, drukverband, nagelprotheses en nagelbeugels)'},
#  {'verzekeraar': 'CZ',
#   'pakket': 'Jongeren',
#   'vergoeding': '€ 70,- (en € 60,- Voetzorg hulpmiddelen zoals zooltjes, tape, drukverband, nagelprotheses en nagelbeugels)'},
#  {'verzekeraar': 'CZ',
#   'pakket': 'Plus',
#   'vergoeding': '€ 115,- (en € 75,- Voetzorg hulpmiddelen zoals zooltjes, tape, drukverband, nagelprotheses en nagelbeugels)'},
#  {'verzekeraar': 'CZ',
#   'pakket': 'Top',
#   'vergoeding': '€ 115,- (en € 75,- Voetzorg hulpmiddelen zoals zooltjes, tape, drukverband, nagelprotheses en nagelbeugels)'},
#  {'verzekeraar': 'CZ',
#   'pakket': 'Gezinnen',
#   'vergoeding': '€ 115,- (en € 60,- Voetzorg hulpmiddelen zoals zooltjes, tape, drukverband, nagelprotheses en nagelbeugels)'},
#  {'verzekeraar': 'CZdirect',
#   'pakket': '-',
#   'vergoeding': 'Geen vergoeding voor podotherapie in de aanvullende verzekeringen.'},
#  {'verzekeraar': 'DSW',
#   'pakket': 'AV Compact',
#   'vergoeding': 'Maximaal € 27,50 per behandeldatum, maximaal 6 behandelingen per kalenderjaar. Steunzolen: geen vergoeding'},
#  {'verzekeraar': 'DSW',
#   'pakket': 'AV Student',
#   'vergoeding': 'Maximaal € 27,50 per behandeldatum, maximaal 6 behandelingen per kalenderjaar. Steunzolen: vergoeding tot maximaal € 55,- per kalenderjaar'},
#  {'verzekeraar': 'DSW',
#   'pakket': 'AV Standaard',
#   'vergoeding': 'Maximaal € 27,50 per behandeldatum, maximaal 6 behandelingen per kalenderjaar. Steunzolen: vergoeding tot maximaal € 55,- per kalenderjaar'},
#  {'verzekeraar': 'DSW',
#   'pakket': 'AV Top',
#   'vergoeding': 'Maximaal € 27,50 per behandeldatum, maximaal 6 behandelingen per kalenderjaar. Steunzolen: vergoeding tot maximaal € 75,- per kalenderjaar'},
#  {'verzekeraar': 'De Friesland',
#   'pakket': 'AV Instap/Budget/Standaard',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'De Friesland',
#   'pakket': 'AV Extra',
#   'vergoeding': 'Max. € 150 per kalenderjaar; steunzolen max. € 125 per 2 kalenderjaren'},
#  {'verzekeraar': 'De Friesland',
#   'pakket': 'AV Optimaal',
#   'vergoeding': 'Max. € 250 per kalenderjaar; steunzolen max. € 125 per 2 kalenderjaren'},
#  {'verzekeraar': 'De Friesland',
#   'pakket': 'AV Frieso Compleet',
#   'vergoeding': 'Max. € 250 per kalenderjaar; steunzolen 100% max. 1x per kalenderjaar'},
#  {'verzekeraar': 'FBTO',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie (en steunzolen).'},
#  {'verzekeraar': 'GarantVerzorgd (gemeentepolis via Menzis)',
#   'pakket': 'GarantVerzorgd 1',
#   'vergoeding': 'Maximaal € 50 voor behandelingen en hulpmiddelen samen indien geen aanspraak op Basisverzekering'},
#  {'verzekeraar': 'GarantVerzorgd (gemeentepolis via Menzis)',
#   'pakket': 'GarantVerzorgd 2',
#   'vergoeding': 'Maximaal € 200 voor behandelingen en hulpmiddelen samen indien geen aanspraak op Basisverzekering'},
#  {'verzekeraar': 'GarantVerzorgd (gemeentepolis via Menzis)',
#   'pakket': 'GarantVerzorgd 3',
#   'vergoeding': 'Maximaal € 250 voor behandelingen en hulpmiddelen samen indien geen aanspraak op Basisverzekering'},
#  {'verzekeraar': 'Gemeente Amsterdam (Zilveren Kruis)',
#   'pakket': 'AV Amsterdam 1',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Gemeente Amsterdam (Zilveren Kruis)',
#   'pakket': 'AV Amsterdam 2',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Gemeente Amsterdam (Zilveren Kruis)',
#   'pakket': 'AV Amsterdam 3',
#   'vergoeding': 'Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Gemeenten Optimaal (Zilveren Kruis)',
#   'pakket': 'Optimaal Aanvullend 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Gemeenten Optimaal (Zilveren Kruis)',
#   'pakket': 'Optimaal Aanvullend 2',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Gemeenten Optimaal (Zilveren Kruis)',
#   'pakket': 'Optimaal Aanvullend 3',
#   'vergoeding': 'Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Hema',
#   'pakket': '-',
#   'vergoeding': 'HEMA stopt met ingang van 1 januari 2025 met het aanbieden van zorgverzekeringen.'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Extra Zorg 1',
#   'vergoeding': '€ 100,- per jaar voor podotherapie en voetbehandelingen en € 125,- voor aanmeten en kosten van steunzolen en therapiezolen'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Extra Zorg 2',
#   'vergoeding': '€ 200,- per jaar voor podotherapie en voetbehandelingen en € 125,- voor aanmeten en kosten van steunzolen en therapiezolen'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Extra Zorg 3',
#   'vergoeding': '€ 300,- per jaar voor podotherapie en voetbehandelingen en € 225,- voor aanmeten en kosten van steunzolen en therapiezolen'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Extra Zorg Basis en Instap',
#   'vergoeding': 'Geen vergoeding voor voetzorg en steunzolen'},
#  {'verzekeraar': 'IZA',
#   'pakket': 'IZA Classic Comfort',
#   'vergoeding': '€ 200,- per jaar voor podotherapie en voetbehandelingen en € 225,- voor aanmeten en kosten van steunzolen en therapiezolen'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg Instap',
#   'vergoeding': 'Geen vergoeding voor podotherapie en steunzolen'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg',
#   'vergoeding': 'Geen vergoeding voor podotherapie en steunzolen'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg + Extra 1',
#   'vergoeding': 'Geen vergoeding voor podotherapie en steunzolen'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg + Extra 2',
#   'vergoeding': '€ 100,- per jaar voor podotherapie en voetbehandelingen en € 125,- voor steunzolen'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'IZZ Zorg voor de Zorg + Extra 3',
#   'vergoeding': '€ 200,- per jaar voor podotherapie en voetbehandelingen en € 125,- voor steunzolen'},
#  {'verzekeraar': 'IZZ Zorgverzekering (door VGZ)',
#   'pakket': 'Bijzonder Bewust',
#   'vergoeding': 'Geen vergoeding voor podotherapie en steunzolen'},
#  {'verzekeraar': 'Ik kies zelf (voorheen Ditzo)',
#   'pakket': 'ZorgBewust',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Ik kies zelf (voorheen Ditzo)',
#   'pakket': 'ZorgBeter',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Ik kies zelf (voorheen Ditzo)',
#   'pakket': 'ZorgBest',
#   'vergoeding': 'Podotherapie en steunzolen max. 75% van de rekening, max. € 250 per jaar'},
#  {'verzekeraar': 'InTwente',
#   'pakket': '-',
#   'vergoeding': 'Vanaf 1 januari 2025 brengt inTwente de zorgverzekering onder bij DSW Zorgverzekeraar.'},
#  {'verzekeraar': 'Interpolis',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie (en steunzolen).'},
#  {'verzekeraar': 'Just',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie en steunzolen.'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'ExtraVerzorgd 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'ExtraVerzorgd 2',
#   'vergoeding': 'Max. € 150,- per kalenderjaar voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'ExtraVerzorgd 3',
#   'vergoeding': 'Max. € 200,- per kalenderjaar voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'JongerenVerzorgd',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'Aanvullend',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Menzis',
#   'pakket': 'Extra Aanvullend',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Mevas',
#   'pakket': '-',
#   'vergoeding': 'Verzekeringspartner van Koninklijke Metaalunie biedt dit jaar een uitgebreid zorgverzekeringspakket op maat voor de Metaal & Techniek sector. Leden kunnen kiezen tussen twee verzekeraars, Zilveren Kruis en De Friesland.'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Instap en Start',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Extra',
#   'vergoeding': '€ 100,- vergoeding voetbehandeling en € 100,- voor steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Compleet',
#   'vergoeding': '€ 150,- vergoeding voetbehandeling en € 150,- voor steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Comfort',
#   'vergoeding': '€ 150,- vergoeding voetbehandeling en € 200,- voor steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Top',
#   'vergoeding': '€ 150,- vergoeding voetbehandeling en 100% voor steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Jij & Compact',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Jij & Gemak',
#   'vergoeding': '€ 70,- vergoeding voetbehandeling en € 60,- voor steunzolen'},
#  {'verzekeraar': 'Nationale Nederlanden',
#   'pakket': 'Jij & Vitaal',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Aanvullend/Aanvullend Fysio Meenemen',
#   'vergoeding': 'Maximaal € 50,- voor voetbehandelingen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Extra aanvullend/Extra Aanvullend Fysio Meenemen',
#   'vergoeding': 'Maximaal € 100,- voor voetbehandelingen en € 100,- voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Uitgebreid/Uitgebreid Fysio Meenemen',
#   'vergoeding': 'Maximaal € 150,- voor voetbehandelingen en € 150,- voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Uitgebreid Vitaal',
#   'vergoeding': 'Max. € 150,- voor voetbehandelingen en € 200,- voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Extra Uitgebreid',
#   'vergoeding': 'Max. € 150,- voor voetbehandelingen en € 200,- voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Compleet',
#   'vergoeding': 'Max. € 150,- voor voetbehandelingen en volledige vergoeding voor steunzolen'},
#  {'verzekeraar': 'OHRA',
#   'pakket': 'Zelfverzekerd Compact',
#   'vergoeding': 'Max. € 50,- voor voetbehandelingen en geen vergoeding voor steunzolen'},
#  {'verzekeraar': 'ONVZ',
#   'pakket': 'Startfit',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'ONVZ', 'pakket': 'Benfit', 'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'ONVZ',
#   'pakket': 'Optifit',
#   'vergoeding': 'Max. € 200 voor andere voetzorg (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'ONVZ',
#   'pakket': 'Topfit',
#   'vergoeding': 'Max. € 500 voor andere voetzorg (inclusief steunzolen) per kalenderjaar'},
#  {'verzekeraar': 'PlusGezond',
#   'pakket': '-',
#   'vergoeding': 'Vanaf 1 november 2024 gaat PlusGezond verder onder de naam Aevitae.'},
#  {'verzekeraar': 'Politie Zorg Polis',
#   'pakket': 'Jongeren PZP',
#   'vergoeding': '€ 70,- voor voetbehandelingen, € 55,-  per jaar voor steunzolen'},
#  {'verzekeraar': 'Politie Zorg Polis',
#   'pakket': 'Basis PZP',
#   'vergoeding': '€ 70,- voor voetbehandelingen, € 55,-  per jaar voor steunzolen'},
#  {'verzekeraar': 'Politie Zorg Polis',
#   'pakket': 'Plus PZP',
#   'vergoeding': '€ 115,- voor voetbehandelingen, € 55,-  per jaar voor steunzolen'},
#  {'verzekeraar': 'Politie Zorg Polis',
#   'pakket': 'Jongeren Start PZP',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Salland Zorgverzekeringen',
#   'pakket': 'Start',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Salland Zorgverzekeringen',
#   'pakket': 'Extra',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Salland Zorgverzekeringen',
#   'pakket': 'Plus',
#   'vergoeding': '75% tot maximaal € 125,- per kalenderjaar (inclusief steunzolen)'},
#  {'verzekeraar': 'Salland Zorgverzekeringen',
#   'pakket': 'Top',
#   'vergoeding': '75% tot maximaal € 250,- per kalenderjaar (inclusief steunzolen)'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Compact AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Jongeren AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar; steunzolen max. € 75,- per kalenderjaar'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Standaard AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar; steunzolen max. € 55,- per kalenderjaar'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Uitgebreide AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar; steunzolen max. € 75,- per kalenderjaar'},
#  {'verzekeraar': 'Stad Holland',
#   'pakket': 'Extra Uitgebreide AV',
#   'vergoeding': 'Max. € 27,50 per behandeldatum, max. 6 behandelingen per kalenderjaar; steunzolen max. € 75,- per kalenderjaar'},
#  {'verzekeraar': 'UMC Zorgverzekering',
#   'pakket': 'Extra Zorg Basis en Instap',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'UMC Zorgverzekering',
#   'pakket': 'Extra Zorg 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'UMC Zorgverzekering',
#   'pakket': 'Extra Zorg 2',
#   'vergoeding': '€ 100,- per jaar en € 125,- voor steunzolen'},
#  {'verzekeraar': 'UMC Zorgverzekering',
#   'pakket': 'Extra Zorg 3',
#   'vergoeding': '€ 100,- per jaar en € 125,- voor steunzolen'},
#  {'verzekeraar': 'United Consumers (VGZ)',
#   'pakket': 'ZorgZeker 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'United Consumers (VGZ)',
#   'pakket': 'ZorgZeker 2',
#   'vergoeding': '€ 100,- budget voor voetbehandelingen; € 70,- voor steunzolen'},
#  {'verzekeraar': 'United Consumers (VGZ)',
#   'pakket': 'ZorgZeker 3',
#   'vergoeding': '€ 200,- budget voor voetbehandelingen; € 125,- voor steunzolen'},
#  {'verzekeraar': 'Univé',
#   'pakket': 'Aanvullend Goed',
#   'vergoeding': 'Geen vergoeding voor podotherapie en voetbehandelingen'},
#  {'verzekeraar': 'Univé',
#   'pakket': 'Aanvullend Beter',
#   'vergoeding': '€ 100 per jaar voor podotherapie en voetbehandelingen en € 70 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'Univé',
#   'pakket': 'Aanvullend Best',
#   'vergoeding': '€ 200 per jaar voor podotherapie en voetbehandelingen en € 100 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'Univé Zorg GemeentePakket',
#   'pakket': 'Compact',
#   'vergoeding': '€ 100 per jaar voor podotherapie en voetbehandelingen en € 70 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'Univé Zorg GemeentePakket',
#   'pakket': 'Compleet',
#   'vergoeding': '€ 300 per jaar voor podotherapie en voetbehandelingen en € 125 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ', 'pakket': 'Instap', 'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Aanvullend Goed',
#   'vergoeding': '€ 100 per jaar voor podotherapie en voetbehandelingen en € 70 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Aanvullend Beter',
#   'vergoeding': '€ 300 per jaar voor podotherapie en voetbehandelingen en € 125 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Aanvullend Best',
#   'vergoeding': '€ 500 per jaar voor podotherapie en voetbehandelingen en € 180 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Alles-in-1 VGZ Jongpakket',
#   'vergoeding': 'Geen vergoeding voor podotherapie en steunzolen'},
#  {'verzekeraar': 'VGZ',
#   'pakket': 'Alles-in-1 VGZ Gezinpakket',
#   'vergoeding': '€ 300 per jaar voor podotherapie en voetbehandelingen en € 125 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ Werkt',
#   'pakket': 'Werkt Basis en Instap',
#   'vergoeding': 'Geen vergoeding voor podotherapie en steunzolen'},
#  {'verzekeraar': 'VGZ Werkt',
#   'pakket': 'Werkt Goed',
#   'vergoeding': '€ 100 per jaar voor podotherapie en voetbehandelingen en € 70 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ Werkt',
#   'pakket': 'Werkt Beter',
#   'vergoeding': '€ 300 per jaar voor podotherapie en voetbehandelingen en € 125 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ Werkt',
#   'pakket': 'Werkt Best',
#   'vergoeding': '€ 500 per jaar voor podotherapie en voetbehandelingen en € 180 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ Zorgt',
#   'pakket': 'VGZ Zorgt Instap',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'VGZ Zorgt',
#   'pakket': 'VGZ Zorgt Goed',
#   'vergoeding': '€ 100 per jaar voor podotherapie en voetbehandelingen en € 70 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ Zorgt',
#   'pakket': 'VGZ Zorgt Beter',
#   'vergoeding': '€ 300 per jaar voor podotherapie en voetbehandelingen en € 125 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZ Zorgt',
#   'pakket': 'VGZ Zorgt Best',
#   'vergoeding': '€ 500 per jaar voor podotherapie en voetbehandelingen en € 180 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'VGZbewuzt',
#   'pakket': '-',
#   'vergoeding': 'Geen vergoeding voor podotherapie en voetbehandelingen'},
#  {'verzekeraar': 'VinkVink',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie en steunzolen.'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Start',
#   'vergoeding': 'Geen vergoeding voor voetzorg en steunzolen'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Plus',
#   'vergoeding': 'Geen vergoeding voor voetzorg en steunzolen'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Optimaal',
#   'vergoeding': '€ 200,- per jaar voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Top',
#   'vergoeding': '€ 500,- per jaar voor voetzorg (inclusief steunzolen)'},
#  {'verzekeraar': 'VvAA',
#   'pakket': 'Excellent',
#   'vergoeding': '100% voor voetzorg, € 500 euro voor steunzolen'},
#  {'verzekeraar': 'ZEKUR',
#   'pakket': 'Extra ZEKUR',
#   'vergoeding': '€ 200 per jaar voor podotherapie en voetbehandelingen; € 125 per jaar voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'ZieZo van Zilveren Kruis',
#   'pakket': '-',
#   'vergoeding': 'Deze zorgverzekeraar biedt vanuit de aanvullende verzekering geen vergoeding voor podotherapie (en steunzolen).'},
#  {'verzekeraar': 'Zilveren Kruis',
#   'pakket': 'Aanvullend 1 Ster',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Zilveren Kruis',
#   'pakket': 'Aanvullend 2 Sterren',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Zilveren Kruis',
#   'pakket': 'Aanvullend 3 Sterren',
#   'vergoeding': 'Max. € 150,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Zilveren Kruis',
#   'pakket': 'Aanvullend 4 Sterren',
#   'vergoeding': 'Max. € 200,- per kalenderjaar (inclusief 1 paar steunzolen)'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV Basis',
#   'vergoeding': 'Max. € 50,- vergoeding per kalenderjaar en 50% voor steunzolen tot maximaal € 35,-'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV Standaard',
#   'vergoeding': 'Max. € 50,- vergoeding per kalenderjaar en 50% voor steunzolen tot maximaal € 35,-'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV Top',
#   'vergoeding': 'Max. € 100,- vergoeding per kalenderjaar en tot max. € 70,- voor steunzolen'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV Plus',
#   'vergoeding': 'Max. € 100,- vergoeding per kalenderjaar en tot max. € 70,- voor steunzolen'},
#  {'verzekeraar': 'Zorg en Zekerheid',
#   'pakket': 'AV GeZZin',
#   'vergoeding': 'Max. € 100,- vergoeding per kalenderjaar en tot max. € 70,- voor steunzolen'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 1',
#   'vergoeding': 'Geen vergoeding'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 2',
#   'vergoeding': '€ 100 per jaar voor podotherapie en voetbehandelingen, geen vergoeding voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 3',
#   'vergoeding': '€ 100 per jaar voor podotherapie en voetbehandelingen, geen vergoeding voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 4',
#   'vergoeding': '€ 200 per jaar voor podotherapie en voetbehandelingen Geen vergoeding voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'Zorgzaam',
#   'pakket': 'Zorgzaam Aanvullend Ster 5',
#   'vergoeding': '€ 200 per jaar voor podotherapie en voetbehandelingen € 70 voor aanmeten en kosten van steunzolen en therapiezolen.'},
#  {'verzekeraar': 'a.s.r. (De Amersfoortse)',
#   'pakket': 'Start',
#   'vergoeding': 'Podotherapie max. € 100,- per jaar  Steunzolen* krijg je vergoed tot maximaal € 50 per jaar'},
#  {'verzekeraar': 'a.s.r. (De Amersfoortse)',
#   'pakket': 'Extra',
#   'vergoeding': 'Podotherapie max. € 250,- per jaar Steunzolen* krijg je vergoed tot maximaal € 100 per jaar'},
#  {'verzekeraar': 'a.s.r. (De Amersfoortse)',
#   'pakket': 'Uitgebreid',
#   'vergoeding': 'Podotherapie max. € 500,- per jaar Steunzolen* krijg je vergoed tot maximaal € 150 per jaar'},
#  {'verzekeraar': 'a.s.r. (De Amersfoortse)',
#   'pakket': 'Optimaal',
#   'vergoeding': 'Podotherapie krijg je volledig vergoed, zonder maximumbedrag per jaar Steunzolen* krijg je vergoed tot maximaal € 200 per jaar'},
#  {'verzekeraar': 'a.s.r. (De Amersfoortse)',
#   'pakket': '* Steunzolen',
#   'vergoeding': 'Je hebt een verwijzing van de behandelend arts, podotherapeut, registerpodoloog of podoposturaal therapeut. De steunzolen of therapeutische zolen worden geleverd door een orthopedisch schoenmaker, podotherapeut, registerpodoloog of podoposturaal therapeu'}]
